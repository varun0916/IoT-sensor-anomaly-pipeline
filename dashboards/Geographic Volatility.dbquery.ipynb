-- %%
SELECT 
    l.region_name, 
    AVG(f.z_score) as avg_volatility
FROM gold.fact_iot_events f
JOIN gold.dim_location_environment l ON f.location_sk = l.location_sk
GROUP BY 1;
-- Out:
-- Databricks visualization. Run in Databricks to view.
