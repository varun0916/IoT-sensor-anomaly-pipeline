-- %%
SELECT 
    s.sensor_identifier,
    f.event_timestamp,
    f.sensor_reading_value,
    f.z_score
FROM gold.fact_iot_events f
JOIN gold.dim_sensor_master s ON f.sensor_sk = s.sensor_sk
ORDER BY f.event_timestamp ASC;
-- Out:
-- Databricks visualization. Run in Databricks to view.
